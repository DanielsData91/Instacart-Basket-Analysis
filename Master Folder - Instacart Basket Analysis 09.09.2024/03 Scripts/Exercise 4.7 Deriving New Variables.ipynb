# %% [markdown]
# ## 4.7 Deriving New Variables

# %% [markdown]
# ### This script contains the following points:
#
# #### 1. Importing the data
# #### 2. If-Statement
# #### 3. Exporting the data

# %% [markdown]
# # 1. Importing the data

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/daniel/Desktop/LEBEN/Data Analyst/Data Analytics Course/Data Immersion/Achievement 4/Master Folder - Instacart Basket Analysis 09.09.2024'

# %%
#Importing the products.csv data from the original data folder

df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))

# %%
#Checking the values for correct import

df_ords_prods_merge
# Out:
#           order_id  user_id  order_number  orders_day_of_the_week  \
# 0          2539329        1             1                       2
# 1          2539329        1             1                       2
# 2          2539329        1             1                       2
# 3          2539329        1             1                       2
# 4          2539329        1             1                       2
# ...            ...      ...           ...                     ...
# 32404854   2977660   206209            13                       1
# 32404855   2977660   206209            13                       1
# 32404856   2977660   206209            13                       1
# 32404857   2977660   206209            13                       1
# 32404858   2977660   206209            13                       1
#
#           order_hour_of_day  days_since_last_order  product_id  \
# 0                         8                    0.0         196
# ...

# %% [markdown]
# # 2. If-Statments

# %% [markdown]
# ### 2.1 If-Statements with User-Defined Functions - SUBSET

# %%
#Creating a subset of the data frame to avoid any potential memory issues

df_subset = df_ords_prods_merge[:1000000]

# %%
#Defining a function to add price labels to the products

def price_label(row):

    if row['prices'] <= 5:
        return 'Low-range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid-range product'
    elif row['prices'] > 15:
        return 'High-range product'
    else: return 'Not enough data'

# %%
#Apply the function for the price labels.

df_subset['price_range'] = df_subset.apply(price_label, axis=1)
# Out:
# /var/folders/y8/whbdk63x63398jrksgc7pp0r0000gn/T/ipykernel_3611/3670583677.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['price_range'] = df_subset.apply(price_label, axis=1)

# %%
#Checking the frequency of the new column

df_subset['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product     673183
# Low-range product     314392
# High-range product     12425
# Name: count, dtype: int64

# %%
df_subset['prices'].max()
# Out:
# 99999.0

# %% [markdown]
# ### 2.2 If-Statements with the loc() Function - SUBSET

# %%
#loc function to create a condition for the high-range products, above 15

df_subset.loc[df_subset['prices'] > 15, 'price_range_loc'] = 'High range product'

# %%
#loc function to create a condition for the mid-range products, between 5 - 15, and equal to 15

df_subset.loc[(df_subset['prices'] <= 15) & (df_subset['prices'] > 5), 'price_range_loc'] = 'Mid range product'

# %%
#loc function to create a condition for the low-range products, below and equal to 5

df_subset.loc[df_subset['prices'] <= 5, 'price_range_loc'] = 'Low range product'

# %%
#Check the frequency of the new column

df_subset['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid range product     673183
# Low range product     314392
# High range product     12425
# Name: count, dtype: int64

# %% [markdown]
# ### 2.3 If-Statements with the loc() Function - DATAFRAME

# %%
#loc function to create a condition for the high-range products, above 15

df_ords_prods_merge.loc[df_ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High range product'

# %%
#loc function to create a condition for the mid-range products, between 5 - 15, and equal to 15

df_ords_prods_merge.loc[(df_ords_prods_merge['prices'] <= 15) & (df_ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid range product'

# %%
#loc function to create a condition for the low-range products, below and equal to 5

df_ords_prods_merge.loc[df_ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low range product'

# %%
#Check the frequency of the new column

df_ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid range product     21860860
# Low range product     10126321
# High range product      417678
# Name: count, dtype: int64

# %% [markdown]
# ### 2.4 If-Statements with For-Loops - DATAFRAME

# %% [markdown]
# #### 2.4.1 Busiest days of the week

# %%
#Check for the frequency of each day to determine which are the busiest and less busy days of the week

df_ords_prods_merge['orders_day_of_the_week'].value_counts(dropna = False)
# Out:
# orders_day_of_the_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
#Create a For-Loop function to create results to create a new column that displays the degree of capacity for each day of the week

result = []

for value in df_ords_prods_merge["orders_day_of_the_week"]:
    if value == 0:
        result.append("Bussiest day")
    elif value == 4:
        result.append("least busy")
    else:
        result.append("Regularly busy")

# %%
#Check on the result of the for-loop function

result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
#Create a new column named busiest_day to display the degree of capacity per day

df_ords_prods_merge['busiest_day'] = result

# %%
#Check for the frequency of the three labels

df_ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Bussiest day       6204182
# least busy         3783802
# Name: count, dtype: int64

# %%
#Busiest days update: Create a For-Loop function to create results to create a new column that displays the degree of capacity for each day of the week


result = []

for value in df_ords_prods_merge["orders_day_of_the_week"]:
    if value in [0, 1]:
        result.append("Busiest days")
    elif value in [3, 4]:
        result.append("Slowest days")
    else:
        result.append("Regular days")

# %%
#Create a new column named busiest_day_update to display the degree of capacity per day

df_ords_prods_merge['busiest_day_update'] = result

# %%
#Check the values for accuracy

df_ords_prods_merge['busiest_day_update']
# Out:
# 0           Regular days
# 1           Regular days
# 2           Regular days
# 3           Regular days
# 4           Regular days
#                 ...
# 32404854    Busiest days
# 32404855    Busiest days
# 32404856    Busiest days
# 32404857    Busiest days
# 32404858    Busiest days
# Name: busiest_day_update, Length: 32404859, dtype: object

# %%
df_ords_prods_merge['busiest_day_update'].value_counts(dropna = False)
# Out:
# busiest_day_update
# Regular days    12916111
# Busiest days    11864412
# Slowest days     7624336
# Name: count, dtype: int64

# %% [markdown]
# #### Observation, difference between before and after the update:
# Taking two days for "busiest" and "slowest" and three days for the "regular" label into account creates a more accurate distribution of the capacity Instacart has on certain days. In addition, it makes a clearer understanding of when it is recommended to place more ads to engage with potential customers and on the other hand when ads are more likely to be overlooked due to less traffic.

# %% [markdown]
# #### 2.4.2 Busiest hours of the days

# %%
#Check for the frequency of each hour to determine which are the busiest and less busy hours of the day

df_ords_prods_merge['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
#Create a For-Loop function to create results to create a new column that displays the degree of capacity for each hour of the day

result = []

for value in df_ords_prods_merge["order_hour_of_day"]:
    if value in [10, 11, 14, 15, 13, 12, 16, 9]:
        result.append("Most orders")
    elif value in [17, 8, 18, 19, 20, 7, 21, 22]:
        result.append("Average orders")
    else:
        result.append("Fewest orders")

# %%
result
# Out:
# ['Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
# ...

# %%
#Create a new column named busiest_hours_of_the_day to display the degree of capacity per hour

df_ords_prods_merge['busiest_hours_of_the_day'] = result

# %%
df_ords_prods_merge['busiest_hours_of_the_day'].value_counts(dropna = False)
# Out:
# busiest_hours_of_the_day
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: count, dtype: int64

# %% [markdown]
# # 3. Export

# %%
#Exporting the merged data frame to a pkl format
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined_new.pkl'))
